# %%
# !python HeadTracking.py
# Out:
# Successfully loaded imagenet pretrained weights from "C:\Users\amart/.cache\torch\checkpoints\osnet_ibn_x1_0_imagenet.pth"
# Building train transforms ...
# + resize to 224x224
# + random flip
# + to torch tensor of range [0, 1]
# + normalization (mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# Building test transforms ...
# + resize to 224x224
# + to torch tensor of range [0, 1]
# + normalization (mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# 00000001.jpg
# Length of Boxes is:  3
# 00000002.jpg
# Length of Boxes is:  3
# person1 matches with head0  and min distance is 44.8985140461009
# person2 matches with head1  and min distance is 60.775305589660995
# person3 matches with head2  and min distance is 338.82053510239353
# 00000003.jpg
# Length of Boxes is:  3
# person1 matches with head0  and min distance is 60.75646396377124
# person2 matches with head2  and min distance is 90.01542058447376
# person3 matches with head1  and min distance is 194.6341799972579
# ...
